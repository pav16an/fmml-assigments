# %% [markdown]
# <a href="https://colab.research.google.com/github/pav16an/fmml-assigments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 05:08:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  99.8MB/s    in 0.7s
#
# 2023-05-05 05:08:29 (99.8 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31960   1306.3895v2  We carefully investigate the on-line version o...    cs
# 5786    1206.4673v1  We consider the problem of sparse variable sel...    cs
# 33083  1802.03482v1  The continuation method is a popular approach ...    cs
# 34288  1507.02205v2  This paper addresses the question of how langu...    cs
# 365    1712.02734v2  With access to large datasets, deep neural net...  stat
# ...             ...                                                ...   ...
# 15013  1604.08633v2  Recent work on word ordering has argued that s...    cs
# 10977   1307.0846v1  We propose a novel sparse preference learning/...  stat
# 36563  1503.04260v1  We analyse in this paper the data collected in...    cs
# 31487  1803.05266v2  Estimating the uncertainty in image registrati...    cs
# 20141   1411.3346v1  This paper develops the idea of membership fun...    cs
#
#                                                    title  year  \
# 31960                   On-line PCA with Optimal Regrets  2013
# 5786                        Group Sparse Additive Models  2012
# 33083  A Continuation Method for Discrete Optimizatio...  2018
# 34288  Talking to the crowd: What do people react to ...  2015
# 365    Using Rule-Based Labels for Weak Supervised Le...  2017
# ...                                                  ...   ...
# 15013                       Word Ordering Without Syntax  2016
# 10977                    Semi-supervised Ranking Pursuit  2013
# 36563  Quantum Structure of Negation and Conjunction ...  2015
# 31487       On the Ambiguity of Registration Uncertainty  2018
# 20141  Membership Function Assignment for Elements of...  2014
#
#                                                 keywords
# 31960  [carefully, investigate, algorithm, dimensiona...
# 5786   [selection, nonparametric, knowledge, structur...
# 33083  [continuation, optimization, minimized, effici...
# 34288  [addresses, community, discussion, importance,...
# 365    [recognition, chemistry, inherently, fragmente...
# ...                                                  ...
# 15013  [syntactic, structure, important, effectively,...
# 10977  [preference, learningranking, algorithm, algor...
# 36563  [collected, experiments, performed, combinatio...
# 31487  [estimating, uncertainty, registration, provid...
# 20141  [membership, assignment, subsequently, members...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31960    [carefully, investigate, algorithm, dimensiona...
# 5786     [selection, nonparametric, knowledge, structur...
# 33083    [continuation, optimization, minimized, effici...
# 34288    [addresses, community, discussion, importance,...
# 365      [recognition, chemistry, inherently, fragmente...
#                                ...
# 21577    [sufficient, dimension, reduction, dimensional...
# 6583     [multivariate, distributions, decomposed, univ...
# 6565     [biological, represent, represent, relational,...
# 6240     [attractive, artificial, intelligence, supervi...
# 10482    [algorithm, convergence, accelerated, algorith...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8859 words.
# Out of those 4636 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9c7adefb-1acc-4ad5-9561-5055f1d9be70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c7adefb-1acc-4ad5-9561-5055f1d9be70")) {                    Plotly.newPlot(                        "9c7adefb-1acc-4ad5-9561-5055f1d9be70",                        [{"x":["eigenvalue","instances","negativity","considering","investigate","exponentiated","carefully","different","outperforms","algorithm","dimensional","optimally","qualitatively","literature","essentially","compression","furthermore","projected","extension","algorithms","efficient","selection","simulation","experiment","nonparametric","knowledge","parametric","encourage","variables","prediction","generalize","identifying","information","comparative","structure","demonstrate","thresholding","coordinate","structural","exploiting","competing","substantially","functional","constructing","covariates","condition","effectiveness","classification","applications","efficiency","gracefully","application","implement","complicated","objective","important","technique","complexity","efficiently","approximation","minimized","competitive","guaranteed","continuation","particularly","understood","computational","gradually","transform","transformation","applicability","optimization","messenger","experimental","addresses","community","annotated","importance","discussion","discussions","databases","properties","supervised","generalizable","inherently","conventional","unlabeled","incorporates","modalities","development","approaches","effective","transferable","chemistry","originally","indicating","architecture","contemporary","recognition","therefore","concentrated","generalized","occurrence","variational","stochastic","continuously","dynamical","accessible","inference","experiments","statistics","evolution","processes","approximate","tractable","temporally","interesting","continuous","prevalent","parameters","scalability","clustering","alliterative","manuscripts","published","quantified","methodology","preparation","arithmetic","addressed","analyzing","generalization","statistical","computing","langlands","activations","factorial","theoretically","practical","questions","covariance","describes","systematically","accurately","rectified","corresponding","investigations","relatively","available","simulations","numerical","distribution","approximated","particular","correspondence","reinforcement","factorization","appealing","decomposes","increased","components","bottleneck","framework","occupancy","functions","generalizes","sensitivity","alternative","represents","environments","observations","successor","including","representations","predictor","regression","probability","modifications","convergence","estimation","parallelization","algorithmic","regularized","empirically","distributed","clickstream","environment","regularization","architectures","inequalities","nontrivial","violation","sequences","constraints","explanation","progressively","inequality","graphical","introduce","influence"],"y":[7,85,3,61,137,3,33,717,258,832,184,18,30,130,28,55,155,18,76,583,404,170,77,87,18,324,43,25,162,225,49,79,708,43,342,595,23,26,71,72,28,38,60,44,3,41,211,501,441,133,2,246,67,33,179,374,245,235,170,103,20,126,38,4,80,24,292,17,51,57,43,349,2,389,54,74,70,84,34,10,64,182,194,7,19,105,34,26,31,123,451,230,4,4,14,12,234,10,359,135,5,81,25,57,139,19,24,13,209,557,60,65,98,109,27,20,79,96,6,268,39,126,0,3,31,14,64,7,11,37,41,118,142,110,0,16,3,35,127,66,18,75,21,58,9,133,12,64,282,60,89,218,27,259,22,106,32,13,7,38,91,12,544,7,239,28,33,85,48,83,86,1,234,245,13,140,195,16,121,215,8,47,43,57,97,1,128,85,124,9,7,6,92,158,16,10,12,51,325,67],"type":"bar"},{"x":["eigenvalue","instances","negativity","considering","investigate","expo ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4636,), (4636, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>Ontologies</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Requirements</span> <span style=''>Patterns</span> <span style=''>in</span> <span style=''>Use</span> <span style=''>Cases</span> <br/><br/><span style=''>Use</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>specifications</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style='background-color:rgba(0, 255, 0, 0.5106382978723405);'>description</span> <span style=''>They</span> <span style=''>allow</span> <span style=''>joining</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style=''>modeling</span> <span style=''>space</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>stakeholders</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style=''>needs</span> <span style=''>of</span> <span style=''>the</span> <span style=''>software</span> <span style=''>engineer</span> <span style=''>and</span> <span style=''>analyst</span> <span style=''>involved</span> <span style=''>in</span> <span style=''>the</span> <span style=''>process</span> <span style=''>While</span> <span style=''>use</span> <span style=''>cases</span> <span style=''>are</span> <span style=''>not</span> <span style=''>meant</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>formalizing</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5106382978723405);'>description</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>extract</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>relevant</span> <span style='background-color:rgba(0, 255, 0, 0.30506912442396317);'>information</span> <span style=''>from</span> <span style=''>them</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>patterns</span> <span style=''>(common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>with</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>solutions)</span> <span style=''>in</span> <span style=''>support</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>based</span> <span style=''>software</span> <span style='background-color:rgba(0, 255, 0, 0.39772727272727276);'>development</span> <span style=''>approach</span> <span style=''>In</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style='background-color:rgba(0, 25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style=''>and</span> <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparanormal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>local</span> <span style=''>and</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparanormal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>testing</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>single</span> <span style=''>edge</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>subgraph</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>unknown</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>pseudo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style=''>approach</span> <span style=''>In</span> <span style=''>sharp</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>score</span> <span style=''>test</span> <span style=''>method</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>free</span> <span style=''>of</span> <span style=''>tuning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>given</span> <span style=''>an</span> <span style=''>initial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>scope</span> <span style=''>of</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>U</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplier</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style=''>Auto</span> <span style=''>Encoders</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style=''>Models</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contractive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>capture</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3246753246753246);'>generating</span> <span style=''>density</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>corruption</span> <span style=''>noise</span> <span style=''>is</span> <span style=''>Gaussian</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.48684210526315796);'>reconstruction</span> <span style=''>error</span> <span style=''>is</span> <span style=''>the</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>and</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>valued</span> <span style=''>This</span> <span style=''>has</span> <span style=''>led</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.5348837209302326);'>proposals</span> <span style=''>for</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>learned</span> <span style=''>density</span> <span style=''>function</span> <span style=''>using</span> <span style=''>Langevin</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>MCMC</span> <span style=''>However</span> <span style=''>it</span> <span style=''>remained</span> <span style=''>unclear</span> <span style=''>how</span> <span style=''>to</span> <span style=''>connect</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.41891891891891886);'>regularized</span> <span style=''>auto</span> <span style=''>encoders</span> <span style=''>to</span> <span style=''>the</span> <span style=''>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3246753246753246);'>generating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>discrete</span> <span style=''>or</span> <span style=''>using</span> <span style=''>other</span> <span style=''>forms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>corruption</span> <span style=''>process</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.48684210526315 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>InterpNET</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Introspection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Humans</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>On</span> <span style=''>the</span> <span style=''>contrary</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>not</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>bridge</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>new</span> <span style=''>way</span> <span style=''>to</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>inspired</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style=''>evidence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>visual</span> <span style=''>systems</span> <span style=''>inner</span> <span style=''>workings</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>design</span> <span style=''>paradigm</span> <span style=''>termed</span> <span style=''>InterpNET</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifications</span> <span style=''>The</span> <span style=''>success</span> <span style=''>of</span> <span style=''>the</span> <span style=''>module</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>in</span> <span style=''>its</span> <span style=''>internal</span> <span style=''>layer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>While</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>InterpNET</span> <span style=''>could</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08306709265175719)
# 	representation (0.12637557685481007)
# 	processing (0.10685126020589279)
# 	experimental (0.13809016684416045)
# 	segmentation (0.07099751508697195)
# 	information (0.25133120340788073)
# 	different (0.25452609158679446)
# 	detection (0.1253106141285055)
# 	recognition (0.12744053958111465)
# 	convolutional (0.1299254526091587)
#
# Some Statistics words are:
# 	variables (0.1427130610186586)
# 	algorithm (0.38628340897629854)
# 	stochastic (0.14069591527987896)
# 	theoretical (0.15128593040847202)
# 	statistical (0.15431164901664146)
# 	estimation (0.18305597579425115)
# 	distribution (0.1880988401412002)
# 	dimensional (0.19213313161875945)
# 	regression (0.1805345436207766)
# 	inference (0.20827029752899648)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="445c5f3d-2138-457c-9b02-8133e477d36f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("445c5f3d-2138-457c-9b02-8133e477d36f")) {                    Plotly.newPlot(                        "445c5f3d-2138-457c-9b02-8133e477d36f",                        [{"x":["eigenvalue","instances","negativity","considering","investigate","exponentiated","carefully","different","outperforms","algorithm","dimensional","optimally","qualitatively","literature","essentially","compression","furthermore","projected","extension","algorithms","efficient","selection","simulation","experiment","nonparametric","knowledge","parametric","encourage","variables","prediction","generalize","identifying","information","comparative","structure","demonstrate","thresholding","coordinate","structural","exploiting","competing","substantially","functional","constructing","covariates","condition","effectiveness","classification","applications","efficiency","gracefully","application","implement","complicated","objective","important","technique","complexity","efficiently","approximation","minimized","competitive","guaranteed","continuation","particularly","understood","computational","gradually","transform","transformation","applicability","optimization","messenger","experimental","addresses","community","annotated","importance","discussion","discussions","databases","properties","supervised","generalizable","inherently","conventional","unlabeled","incorporates","modalities","development","approaches","effective","transferable","chemistry","originally","indicating","architecture","contemporary","recognition","therefore","concentrated","generalized","occurrence","variational","stochastic","continuously","dynamical","accessible","inference","experiments","statistics","evolution","processes","approximate","tractable","temporally","interesting","continuous","prevalent","parameters","scalability","clustering","alliterative","manuscripts","published","quantified","methodology","preparation","arithmetic","addressed","analyzing","generalization","statistical","computing","langlands","activations","factorial","theoretically","practical","questions","covariance","describes","systematically","accurately","rectified","corresponding","investigations","relatively","available","simulations","numerical","distribution","approximated","particular","correspondence","reinforcement","factorization","appealing","decomposes","increased","components","bottleneck","framework","occupancy","functions","generalizes","sensitivity","alternative","represents","environments","observations","successor","including","representations","predictor","regression","probability","modifications","convergence","estimation","parallelization","algorithmic","regularized","empirically","distributed","clickstream","environment","regularization","architectures","inequalities","nontrivial","violation","sequences","constraints","explanation","progressively","inequality","graphical","introduce","influence","correlations","constraining","contribution","relaxations","homophily","mechanics","characteristics","intelligence","inferring","potential","availability","advantage","questionnaire","fundamental","construct","consistently","personality","successfully","vocabulary","constructs","traditional","comprehensive","differences","identified","dictionary","linguistic","evaluations","automatically","undirected","advantages","predictive","categorical","discrimination","posterior","parameter","quantitatively","dirichlet","arbitrary","documents","allocation","likelihood","principle","discovering","unsupervised","satisfying","distortion","scenarios","constrain","distortions","transfers","transferring","reminiscent","constraint","colorspace","f ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	alliterative
# 	langlands
# 	dissimilarities
# 	cheminformatics
# 	precautions
# 	roadworks
# 	interchangeable
# 	sparsifying
# 	eigendecomposition
# 	tibshirani
# 	backfitting
# 	reversing
# 	collapsing
# 	sparsified
# 	disregarded
# 	recycling
# 	cytometry
# 	readmission
# 	monitored
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	messenger
# 	questionnaire
# 	personality
# 	distortions
# 	photorealistic
# 	photographic
# 	suppresses
# 	photographs
# 	ontological
# 	utilising
# 	contradictory
# 	contextualized
# 	analogies
# 	paraphrase
# 	reflection
# 	psychological
# 	blogosphere
# 	descriptive
# 	observers
# 	negotiation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0482228860574288e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
